# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
                                                      
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 1 | cidreira
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | bathsheba
# Processing Record 6 of Set 1 | banjar
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | san quintin
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | borogontsy
# Processing Record 12 of Set 1 | geraldton
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | vestmanna
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | clyde river
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | daru
# Processing Record 20 of Set 1 | half moon bay
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | saldanha
# Processing Record 24 of Set 1 | torbay
# Processing Record 25 of Set 1 | goure
# Processing Record 26 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | urengoy
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | port blair
# Processing Record 31 of Set 1 | onguday
# Processing Record 32 of Set 1 | qasigiannguit
# Processing Record 33 of Set 1 | japura
# Processing Record 34 of Set 1 | kaspiysk
# Processing Record 35 of Set 1 | belmonte
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | carmen
# Processing Record 38 of Set 1 | khatanga
# Processing Record 39 of Set 1 | flinders
# Processing Record 40 of Set 1 | broome
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 1 | burkhala
# City not found. Skipping...
# Processing Record 48 of Set 1 | dingle
# Processing Record 49 of Set 1 | itarema
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | farah
# Processing Record 2 of Set 2 | iqaluit
# Processing Record 3 of Set 2 | huron
# Processing Record 4 of Set 2 | ostrovnoy
# Processing Record 5 of Set 2 | soto la marina
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | paamiut
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | galesong
# Processing Record 12 of Set 2 | la ronge
# Processing Record 13 of Set 2 | san ignacio
# Processing Record 14 of Set 2 | mahebourg
# Processing Record 15 of Set 2 | igrim
# Processing Record 16 of Set 2 | namtsy
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | balclutha
# Processing Record 21 of Set 2 | alekseyevka
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | atar
# Processing Record 24 of Set 2 | polyarnyy
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | marsa matruh
# Processing Record 27 of Set 2 | tarata
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | auki
# Processing Record 30 of Set 2 | lerwick
# Processing Record 31 of Set 2 | vangaindrano
# Processing Record 32 of Set 2 | naze
# Processing Record 33 of Set 2 | zima
# Processing Record 34 of Set 2 | cap-chat
# Processing Record 35 of Set 2 | sitka
# Processing Record 36 of Set 2 | salalah
# Processing Record 37 of Set 2 | najran
# Processing Record 38 of Set 2 | macaubas
# Processing Record 39 of Set 2 | yagoua
# Processing Record 40 of Set 2 | pleszew
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | yashalta
# Processing Record 43 of Set 2 | mandalgovi
# Processing Record 44 of Set 2 | lata
# Processing Record 45 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 2 | kruisfontein
# Processing Record 47 of Set 2 | anadyr
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | saskylakh
# Processing Record 50 of Set 2 | high rock
# Processing Record 1 of Set 3 | taoudenni
# Processing Record 2 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 3 | port macquarie
# Processing Record 4 of Set 3 | kaitangata
# Processing Record 5 of Set 3 | poronaysk
# Processing Record 6 of Set 3 | airai
# Processing Record 7 of Set 3 | rushden
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | shelton
# Processing Record 10 of Set 3 | srednekolymsk
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | port lincoln
# Processing Record 13 of Set 3 | simbahan
# Processing Record 14 of Set 3 | glenwood springs
# Processing Record 15 of Set 3 | hailar
# Processing Record 16 of Set 3 | faya
# Processing Record 17 of Set 3 | nome
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | codrington
# Processing Record 20 of Set 3 | yulin
# Processing Record 21 of Set 3 | yar-sale
# Processing Record 22 of Set 3 | nikolskoye
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | montepuez
# Processing Record 25 of Set 3 | antofagasta
# Processing Record 26 of Set 3 | dicabisagan
# Processing Record 27 of Set 3 | te anau
# Processing Record 28 of Set 3 | punta arenas
# Processing Record 29 of Set 3 | aksu
# Processing Record 30 of Set 3 | longyearbyen
# Processing Record 31 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 32 of Set 3 | mataura
# Processing Record 33 of Set 3 | fort dodge
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | arraial do cabo
# Processing Record 36 of Set 3 | camacha
# Processing Record 37 of Set 3 | maues
# Processing Record 38 of Set 3 | hithadhoo
# Processing Record 39 of Set 3 | tashla
# Processing Record 40 of Set 3 | ocampo
# Processing Record 41 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 3 | chokurdakh
# Processing Record 43 of Set 3 | aklavik
# Processing Record 44 of Set 3 | esperance
# Processing Record 45 of Set 3 | umm kaddadah
# Processing Record 46 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 47 of Set 3 | arlit
# Processing Record 48 of Set 3 | mitu
# Processing Record 49 of Set 3 | bredasdorp
# Processing Record 50 of Set 3 | cardoso
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | ambon
# Processing Record 3 of Set 4 | broken hill
# Processing Record 4 of Set 4 | norman wells
# Processing Record 5 of Set 4 | husavik
# Processing Record 6 of Set 4 | nokaneng
# Processing Record 7 of Set 4 | saint-philippe
# Processing Record 8 of Set 4 | sorong
# Processing Record 9 of Set 4 | asau
# Processing Record 10 of Set 4 | shenjiamen
# Processing Record 11 of Set 4 | coihaique
# Processing Record 12 of Set 4 | rozivka
# Processing Record 13 of Set 4 | fairbanks
# Processing Record 14 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 4 | mao
# Processing Record 16 of Set 4 | jabinyanah
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | buala
# Processing Record 19 of Set 4 | alice springs
# Processing Record 20 of Set 4 | severo-kurilsk
# Processing Record 21 of Set 4 | tuktoyaktuk
# Processing Record 22 of Set 4 | shimoda
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 4 | muros
# Processing Record 25 of Set 4 | kapaa
# Processing Record 26 of Set 4 | pahrump
# Processing Record 27 of Set 4 | sananduva
# Processing Record 28 of Set 4 | trelleborg
# Processing Record 29 of Set 4 | provideniya
# Processing Record 30 of Set 4 | byron bay
# Processing Record 31 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 32 of Set 4 | talnakh
# Processing Record 33 of Set 4 | sheboygan
# Processing Record 34 of Set 4 | cleveland
# Processing Record 35 of Set 4 | leningradskiy
# Processing Record 36 of Set 4 | sakakah
# Processing Record 37 of Set 4 | alvaraes
# Processing Record 38 of Set 4 | ambovombe
# Processing Record 39 of Set 4 | necochea
# Processing Record 40 of Set 4 | pori
# Processing Record 41 of Set 4 | yacopi
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | chuy
# Processing Record 44 of Set 4 | galdar
# Processing Record 45 of Set 4 | port-gentil
# Processing Record 46 of Set 4 | kayerkan
# Processing Record 47 of Set 4 | yulara
# Processing Record 48 of Set 4 | nizhnyaya omka
# Processing Record 49 of Set 4 | newport
# Processing Record 50 of Set 4 | dhadar
# Processing Record 1 of Set 5 | san francisco del mar
# Processing Record 2 of Set 5 | souillac
# Processing Record 3 of Set 5 | ginir
# Processing Record 4 of Set 5 | koulikoro
# Processing Record 5 of Set 5 | katsuura
# Processing Record 6 of Set 5 | cabo san lucas
# Processing Record 7 of Set 5 | college
# Processing Record 8 of Set 5 | bunia
# Processing Record 9 of Set 5 | kavaratti
# Processing Record 10 of Set 5 | natitingou
# Processing Record 11 of Set 5 | hinton
# Processing Record 12 of Set 5 | maragogi
# Processing Record 13 of Set 5 | berlevag
# Processing Record 14 of Set 5 | san nicolas
# Processing Record 15 of Set 5 | iracoubo
# Processing Record 16 of Set 5 | dunnville
# Processing Record 17 of Set 5 | san patricio
# Processing Record 18 of Set 5 | ovalle
# Processing Record 19 of Set 5 | salinopolis
# Processing Record 20 of Set 5 | sarangani
# Processing Record 21 of Set 5 | sioux lookout
# Processing Record 22 of Set 5 | talaya
# Processing Record 23 of Set 5 | port elizabeth
# Processing Record 24 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 25 of Set 5 | lompoc
# Processing Record 26 of Set 5 | mogadishu
# Processing Record 27 of Set 5 | verkhoyansk
# Processing Record 28 of Set 5 | kamaishi
# Processing Record 29 of Set 5 | avera
# Processing Record 30 of Set 5 | port hardy
# Processing Record 31 of Set 5 | vila franca do campo
# Processing Record 32 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | ossora
# Processing Record 34 of Set 5 | bengkulu
# Processing Record 35 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 5 | guerrero negro
# Processing Record 37 of Set 5 | naryshkino
# Processing Record 38 of Set 5 | mocuba
# Processing Record 39 of Set 5 | hasaki
# Processing Record 40 of Set 5 | caxito
# Processing Record 41 of Set 5 | granada
# Processing Record 42 of Set 5 | los llanos de aridane
# Processing Record 43 of Set 5 | phitsanulok
# Processing Record 44 of Set 5 | faanui
# Processing Record 45 of Set 5 | ust-uda
# Processing Record 46 of Set 5 | turukhansk
# Processing Record 47 of Set 5 | vardo
# Processing Record 48 of Set 5 | coahuayana
# Processing Record 49 of Set 5 | abu dhabi
# Processing Record 50 of Set 5 | sobolevo
# Processing Record 1 of Set 6 | chase
# Processing Record 2 of Set 6 | dalby
# Processing Record 3 of Set 6 | jutai
# Processing Record 4 of Set 6 | neiafu
# Processing Record 5 of Set 6 | tessalit
# Processing Record 6 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 6 | dongsheng
# Processing Record 8 of Set 6 | ancud
# Processing Record 9 of Set 6 | conde
# Processing Record 10 of Set 6 | birao
# Processing Record 11 of Set 6 | taltal
# Processing Record 12 of Set 6 | el alto
# Processing Record 13 of Set 6 | ambilobe
# Processing Record 14 of Set 6 | chumikan
# Processing Record 15 of Set 6 | champerico
# Processing Record 16 of Set 6 | port hedland
# Processing Record 17 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 6 | wajir
# Processing Record 19 of Set 6 | ushtobe
# Processing Record 20 of Set 6 | grand-santi
# Processing Record 21 of Set 6 | tabuk
# Processing Record 22 of Set 6 | cherskiy
# Processing Record 23 of Set 6 | portland
# Processing Record 24 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 6 | cururupu
# Processing Record 26 of Set 6 | kakonko
# Processing Record 27 of Set 6 | poum
# Processing Record 28 of Set 6 | pimentel
# Processing Record 29 of Set 6 | mombetsu
# Processing Record 30 of Set 6 | waingapu
# Processing Record 31 of Set 6 | alofi
# Processing Record 32 of Set 6 | buraydah
# Processing Record 33 of Set 6 | ilheus
# Processing Record 34 of Set 6 | fare
# Processing Record 35 of Set 6 | pevek
# Processing Record 36 of Set 6 | zyryanka
# Processing Record 37 of Set 6 | samarai
# Processing Record 38 of Set 6 | tukrah
# Processing Record 39 of Set 6 | hay river
# Processing Record 40 of Set 6 | oussouye
# Processing Record 41 of Set 6 | omboue
# Processing Record 42 of Set 6 | ola
# Processing Record 43 of Set 6 | desterro
# Processing Record 44 of Set 6 | vostok
# Processing Record 45 of Set 6 | bethlehem
# Processing Record 46 of Set 6 | ust-nera
# Processing Record 47 of Set 6 | ulaangom
# Processing Record 48 of Set 6 | emba
# Processing Record 49 of Set 6 | manadhoo
# Processing Record 50 of Set 6 | lenger
# Processing Record 1 of Set 7 | sidi ali
# Processing Record 2 of Set 7 | herat
# Processing Record 3 of Set 7 | clearwater
# Processing Record 4 of Set 7 | paris
# Processing Record 5 of Set 7 | oranjestad
# Processing Record 6 of Set 7 | porto walter
# Processing Record 7 of Set 7 | meulaboh
# Processing Record 8 of Set 7 | jalingo
# Processing Record 9 of Set 7 | balkanabat
# Processing Record 10 of Set 7 | kuytun
# Processing Record 11 of Set 7 | lavrentiya
# Processing Record 12 of Set 7 | bubaque
# Processing Record 13 of Set 7 | talara
# Processing Record 14 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 7 | tasiilaq
# Processing Record 18 of Set 7 | ponta delgada
# Processing Record 19 of Set 7 | amboise
# Processing Record 20 of Set 7 | porbandar
# Processing Record 21 of Set 7 | biak
# Processing Record 22 of Set 7 | richards bay
# Processing Record 23 of Set 7 | terrace bay
# Processing Record 24 of Set 7 | mattru
# Processing Record 25 of Set 7 | znamenskoye
# Processing Record 26 of Set 7 | scarborough
# Processing Record 27 of Set 7 | pitimbu
# Processing Record 28 of Set 7 | taki
# Processing Record 29 of Set 7 | san cristobal
# Processing Record 30 of Set 7 | grand-lahou
# Processing Record 31 of Set 7 | kabarnet
# Processing Record 32 of Set 7 | mehamn
# Processing Record 33 of Set 7 | westport
# Processing Record 34 of Set 7 | tynda
# Processing Record 35 of Set 7 | deputatskiy
# Processing Record 36 of Set 7 | anantapur
# Processing Record 37 of Set 7 | kommunar
# Processing Record 38 of Set 7 | eyl
# Processing Record 39 of Set 7 | cartagena del chaira
# Processing Record 40 of Set 7 | hervey bay
# Processing Record 41 of Set 7 | pajapan
# Processing Record 42 of Set 7 | sao joao da barra
# Processing Record 43 of Set 7 | isangel
# Processing Record 44 of Set 7 | kahului
# Processing Record 45 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 7 | sao filipe
# Processing Record 47 of Set 7 | mumford
# Processing Record 48 of Set 7 | takoradi
# Processing Record 49 of Set 7 | klyuchi
# Processing Record 50 of Set 7 | gizo
# Processing Record 1 of Set 8 | ratnagiri
# Processing Record 2 of Set 8 | pyskowice
# Processing Record 3 of Set 8 | argir
# Processing Record 4 of Set 8 | fortuna
# Processing Record 5 of Set 8 | sembe
# Processing Record 6 of Set 8 | marfino
# Processing Record 7 of Set 8 | saint-joseph
# Processing Record 8 of Set 8 | tiznit
# Processing Record 9 of Set 8 | grindavik
# Processing Record 10 of Set 8 | praya
# Processing Record 11 of Set 8 | dhidhdhoo
# Processing Record 12 of Set 8 | jubb jannin
# City not found. Skipping...
# Processing Record 13 of Set 8 | vicar
# Processing Record 14 of Set 8 | abapo
# Processing Record 15 of Set 8 | colares
# Processing Record 16 of Set 8 | lima
# Processing Record 17 of Set 8 | olafsvik
# Processing Record 18 of Set 8 | clermont
# Processing Record 19 of Set 8 | chancay
# Processing Record 20 of Set 8 | saint george
# Processing Record 21 of Set 8 | fort saint james
# Processing Record 22 of Set 8 | touros
# Processing Record 23 of Set 8 | ayagoz
# Processing Record 24 of Set 8 | johnson city
# Processing Record 25 of Set 8 | severnyy
# Processing Record 26 of Set 8 | tricase
# Processing Record 27 of Set 8 | pictou
# Processing Record 28 of Set 8 | hamilton
# Processing Record 29 of Set 8 | high level
# Processing Record 30 of Set 8 | sipoo
# Processing Record 31 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 33 of Set 8 | stabat
# Processing Record 34 of Set 8 | grand gaube
# Processing Record 35 of Set 8 | mount gambier
# Processing Record 36 of Set 8 | tazmalt
# Processing Record 37 of Set 8 | jibuti
# Processing Record 38 of Set 8 | okha
# Processing Record 39 of Set 8 | nurota
# Processing Record 40 of Set 8 | cacador
# Processing Record 41 of Set 8 | yucca valley
# Processing Record 42 of Set 8 | sumbawanga
# Processing Record 43 of Set 8 | ulaanbaatar
# Processing Record 44 of Set 8 | puerto del rosario
# Processing Record 45 of Set 8 | nadym
# Processing Record 46 of Set 8 | manokwari
# Processing Record 47 of Set 8 | vanimo
# Processing Record 48 of Set 8 | valle de allende
# Processing Record 49 of Set 8 | egvekinot
# Processing Record 50 of Set 8 | bairiki
# Processing Record 1 of Set 9 | bijapur
# Processing Record 2 of Set 9 | bethel
# Processing Record 3 of Set 9 | itaueira
# Processing Record 4 of Set 9 | muskegon
# Processing Record 5 of Set 9 | dunedin
# Processing Record 6 of Set 9 | san francisco
# Processing Record 7 of Set 9 | bilibino
# Processing Record 8 of Set 9 | rio pardo
# Processing Record 9 of Set 9 | rosarito
# Processing Record 10 of Set 9 | diffa
# Processing Record 11 of Set 9 | yarada
# Processing Record 12 of Set 9 | tsiroanomandidy
# Processing Record 13 of Set 9 | huarmey
# Processing Record 14 of Set 9 | ust-kuyga
# Processing Record 15 of Set 9 | hillsborough
# Processing Record 16 of Set 9 | teluk nibung
# Processing Record 17 of Set 9 | shache
# Processing Record 18 of Set 9 | baykit
# Processing Record 19 of Set 9 | dakar
# Processing Record 20 of Set 9 | vicuna
# Processing Record 21 of Set 9 | santander
# Processing Record 22 of Set 9 | fort nelson
# Processing Record 23 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 9 | kaspiyskiy
# Processing Record 25 of Set 9 | luanda
# Processing Record 26 of Set 9 | diego de almagro
# Processing Record 27 of Set 9 | magadan
# Processing Record 28 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 29 of Set 9 | wuda
# Processing Record 30 of Set 9 | seoul
# Processing Record 31 of Set 9 | ous
# Processing Record 32 of Set 9 | acapulco
# Processing Record 33 of Set 9 | port augusta
# Processing Record 34 of Set 9 | agua preta
# Processing Record 35 of Set 9 | sawtell
# Processing Record 36 of Set 9 | quatre cocos
# Processing Record 37 of Set 9 | kainantu
# Processing Record 38 of Set 9 | conceicao do araguaia
# Processing Record 39 of Set 9 | zakharovo
# Processing Record 40 of Set 9 | moron
# Processing Record 41 of Set 9 | shitanjing
# Processing Record 42 of Set 9 | akcakoca
# Processing Record 43 of Set 9 | tanda
# Processing Record 44 of Set 9 | darnah
# Processing Record 45 of Set 9 | astaneh-ye ashrafiyeh
# Processing Record 46 of Set 9 | hami
# Processing Record 47 of Set 9 | lorengau
# Processing Record 48 of Set 9 | miram shah
# Processing Record 49 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 9 | nouadhibou
# Processing Record 1 of Set 10 | serebryanyy bor
# Processing Record 2 of Set 10 | magnor
# Processing Record 3 of Set 10 | jiaozuo
# Processing Record 4 of Set 10 | coquimbo
# Processing Record 5 of Set 10 | sahaswan
# Processing Record 6 of Set 10 | krasnyy chikoy
# Processing Record 7 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 8 of Set 10 | mayskiy
# Processing Record 9 of Set 10 | sorland
# Processing Record 10 of Set 10 | karaton
# Processing Record 11 of Set 10 | gamba
# Processing Record 12 of Set 10 | ekhabi
# Processing Record 13 of Set 10 | jinchang
# Processing Record 14 of Set 10 | wajid
# Processing Record 15 of Set 10 | bonavista
# Processing Record 16 of Set 10 | le port
# Processing Record 17 of Set 10 | sola
# Processing Record 18 of Set 10 | sodertalje
# City not found. Skipping...
# Processing Record 19 of Set 10 | kysyl-syr
# Processing Record 20 of Set 10 | batemans bay
# Processing Record 21 of Set 10 | esterhazy
# Processing Record 22 of Set 10 | laguna
# Processing Record 23 of Set 10 | adre
# Processing Record 24 of Set 10 | kudahuvadhoo
# Processing Record 25 of Set 10 | lucea
# Processing Record 26 of Set 10 | marsaxlokk
# Processing Record 27 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 28 of Set 10 | huilong
# Processing Record 29 of Set 10 | rocha
# Processing Record 30 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 31 of Set 10 | requena
# Processing Record 32 of Set 10 | san rafael
# Processing Record 33 of Set 10 | gilgit
# Processing Record 34 of Set 10 | rambha
# Processing Record 35 of Set 10 | bugiri
# Processing Record 36 of Set 10 | syracuse
# Processing Record 37 of Set 10 | bigaan
# Processing Record 38 of Set 10 | tuatapere
# Processing Record 39 of Set 10 | tlahualilo
# City not found. Skipping...
# Processing Record 40 of Set 10 | iquique
# Processing Record 41 of Set 10 | bireun
# Processing Record 42 of Set 10 | guane
# Processing Record 43 of Set 10 | saint-louis
# Processing Record 44 of Set 10 | vila velha
# Processing Record 45 of Set 10 | eureka
# Processing Record 46 of Set 10 | labuan
# Processing Record 47 of Set 10 | moengo
# Processing Record 48 of Set 10 | rio grande
# Processing Record 49 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 10 | zeya
# Processing Record 1 of Set 11 | tiksi
# Processing Record 2 of Set 11 | marsabit
# Processing Record 3 of Set 11 | ahipara
# Processing Record 4 of Set 11 | hualahuises
# Processing Record 5 of Set 11 | mogzon
# Processing Record 6 of Set 11 | belyy yar
# Processing Record 7 of Set 11 | kranuan
# Processing Record 8 of Set 11 | minuri
# Processing Record 9 of Set 11 | yazd
# Processing Record 10 of Set 11 | morbach
# Processing Record 11 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 11 | taunggyi
# Processing Record 13 of Set 11 | yeniseysk
# Processing Record 14 of Set 11 | sault sainte marie
# Processing Record 15 of Set 11 | namatanai
# Processing Record 16 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 11 | lakes entrance
# Processing Record 18 of Set 11 | angra
# City not found. Skipping...
# Processing Record 19 of Set 11 | gambela
# Processing Record 20 of Set 11 | sesheke
# Processing Record 21 of Set 11 | vetrisoaia
# Processing Record 22 of Set 11 | hannibal
# Processing Record 23 of Set 11 | flin flon
# Processing Record 24 of Set 11 | cherdyn
# Processing Record 25 of Set 11 | usinsk
# Processing Record 26 of Set 11 | athabasca
# Processing Record 27 of Set 11 | marau
# Processing Record 28 of Set 11 | yarmouth
# Processing Record 29 of Set 11 | nizhniy baskunchak
# Processing Record 30 of Set 11 | bafra
# Processing Record 31 of Set 11 | vysokogornyy
# Processing Record 32 of Set 11 | narsaq
# Processing Record 33 of Set 11 | bacalar
# Processing Record 34 of Set 11 | rodrigues alves
# Processing Record 35 of Set 11 | taicheng
# Processing Record 36 of Set 11 | almaznyy
# Processing Record 37 of Set 11 | zlobin
# Processing Record 38 of Set 11 | inhambane
# Processing Record 39 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 11 | lumphat
# Processing Record 41 of Set 11 | mahajanga
# Processing Record 42 of Set 11 | chambas
# Processing Record 43 of Set 11 | katete
# Processing Record 44 of Set 11 | rayong
# Processing Record 45 of Set 11 | urgut
# Processing Record 46 of Set 11 | khani
# Processing Record 47 of Set 11 | boljarovo
# City not found. Skipping...
# Processing Record 48 of Set 11 | saint-francois
# Processing Record 49 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 50 of Set 11 | selishche
# Processing Record 1 of Set 12 | esna
# Processing Record 2 of Set 12 | biaora
# Processing Record 3 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 4 of Set 12 | itapuranga
# Processing Record 5 of Set 12 | raudeberg
# Processing Record 6 of Set 12 | joensuu
# Processing Record 7 of Set 12 | pisco
# Processing Record 8 of Set 12 | sao joao dos patos
# Processing Record 9 of Set 12 | thinadhoo
# Processing Record 10 of Set 12 | makasar
# Processing Record 11 of Set 12 | sao jose da coroa grande
# Processing Record 12 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 12 | batagay-alyta
# Processing Record 14 of Set 12 | labuhan
# Processing Record 15 of Set 12 | starobaltachevo
# Processing Record 16 of Set 12 | namibe
# Processing Record 17 of Set 12 | pochutla
# Processing Record 18 of Set 12 | voh
# Processing Record 19 of Set 12 | kodinsk
# Processing Record 20 of Set 12 | beringovskiy
# Processing Record 21 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 22 of Set 12 | shingu
# Processing Record 23 of Set 12 | litoral del san juan
# City not found. Skipping...
# Processing Record 24 of Set 12 | guadalajara
# Processing Record 25 of Set 12 | shihezi
# Processing Record 26 of Set 12 | ketchikan
# Processing Record 27 of Set 12 | rawlins
# Processing Record 28 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 29 of Set 12 | zhigansk
# Processing Record 30 of Set 12 | oil city
# Processing Record 31 of Set 12 | saint-augustin
# Processing Record 32 of Set 12 | chapais
# Processing Record 33 of Set 12 | south sioux city
# Processing Record 34 of Set 12 | inuvik
# Processing Record 35 of Set 12 | sept-iles
# Processing Record 36 of Set 12 | meadow lake
# Processing Record 37 of Set 12 | mathathane
# Processing Record 38 of Set 12 | mackay
# Processing Record 39 of Set 12 | karpathos
# Processing Record 40 of Set 12 | ueno
# Processing Record 41 of Set 12 | bandarbeyla
# Processing Record 42 of Set 12 | sur
# Processing Record 43 of Set 12 | udachnyy
# Processing Record 44 of Set 12 | garowe
# Processing Record 45 of Set 12 | santa cruz
# Processing Record 46 of Set 12 | constitucion
# Processing Record 47 of Set 12 | tura
# Processing Record 48 of Set 12 | nanortalik
# Processing Record 49 of Set 12 | sibolga
# Processing Record 50 of Set 12 | nottingham
# Processing Record 1 of Set 13 | thunder bay
# Processing Record 2 of Set 13 | kloulklubed
# Processing Record 3 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 13 | mongoumba
# Processing Record 6 of Set 13 | krasnoarmeysk
# Processing Record 7 of Set 13 | port shepstone
# Processing Record 8 of Set 13 | am timan
# Processing Record 9 of Set 13 | kyabe
# Processing Record 10 of Set 13 | san lorenzo
# Processing Record 11 of Set 13 | san pedro
# Processing Record 12 of Set 13 | el balyana
# City not found. Skipping...
# Processing Record 13 of Set 13 | kurumkan
# Processing Record 14 of Set 13 | naryan-mar
# Processing Record 15 of Set 13 | linhares
# Processing Record 16 of Set 13 | chipinge
# Processing Record 17 of Set 13 | lar gerd
# City not found. Skipping...
# Processing Record 18 of Set 13 | altona
# Processing Record 19 of Set 13 | cedral
# Processing Record 20 of Set 13 | jaciara
# Processing Record 21 of Set 13 | save
# Processing Record 22 of Set 13 | valjala
# City not found. Skipping...
# Processing Record 23 of Set 13 | luderitz
# Processing Record 24 of Set 13 | riyadh
# Processing Record 25 of Set 13 | manjacaze
# Processing Record 26 of Set 13 | eyemouth
# Processing Record 27 of Set 13 | campbell river
# Processing Record 28 of Set 13 | ayutla
# Processing Record 29 of Set 13 | brae
# Processing Record 30 of Set 13 | shirokiy
# Processing Record 31 of Set 13 | pirovskoye
# Processing Record 32 of Set 13 | tazovskiy
# Processing Record 33 of Set 13 | dandong
# Processing Record 34 of Set 13 | pa sang
# Processing Record 35 of Set 13 | cochabamba
# Processing Record 36 of Set 13 | uyo
# Processing Record 37 of Set 13 | vitimskiy
# City not found. Skipping...
# Processing Record 38 of Set 13 | kieta
# Processing Record 39 of Set 13 | urusha
# Processing Record 40 of Set 13 | waddan
# Processing Record 41 of Set 13 | kedrovyy
# Processing Record 42 of Set 13 | sirjan
# Processing Record 43 of Set 13 | kamwenge
# Processing Record 44 of Set 13 | deh rawud
# City not found. Skipping...
# Processing Record 45 of Set 13 | korla
# Processing Record 46 of Set 13 | manga
# Processing Record 47 of Set 13 | teguise
# Processing Record 48 of Set 13 | aripuana
# Processing Record 49 of Set 13 | aswan
# Processing Record 50 of Set 13 | lagoa
# Processing Record 1 of Set 14 | opuwo
# Processing Record 2 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 14 | havoysund
# Processing Record 4 of Set 14 | dinard
# Processing Record 5 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 14 | komsomolskiy
# Processing Record 7 of Set 14 | bonthe
# Processing Record 8 of Set 14 | abbeville
# Processing Record 9 of Set 14 | emerald
# Processing Record 10 of Set 14 | tamorong
# Processing Record 11 of Set 14 | nueve de julio
# Processing Record 12 of Set 14 | manyana
# Processing Record 13 of Set 14 | kalabo
# Processing Record 14 of Set 14 | nelson bay
# Processing Record 15 of Set 14 | krasyliv
# Processing Record 16 of Set 14 | kulhudhuffushi
# Processing Record 17 of Set 14 | lasa
# Processing Record 18 of Set 14 | san juan
# Processing Record 19 of Set 14 | rabo de peixe
# Processing Record 20 of Set 14 | guayaramerin
# Processing Record 21 of Set 14 | rio gallegos
# Processing Record 22 of Set 14 | zabolottya
# City not found. Skipping...
# Processing Record 23 of Set 14 | san luis
# Processing Record 24 of Set 14 | vestmannaeyjar
# Processing Record 25 of Set 14 | sal rei
# Processing Record 26 of Set 14 | sulphur
# Processing Record 27 of Set 14 | loukhi
# Processing Record 28 of Set 14 | burica
# City not found. Skipping...
# Processing Record 29 of Set 14 | esperantinopolis
# Processing Record 30 of Set 14 | danville
# Processing Record 31 of Set 14 | victor harbor
# Processing Record 32 of Set 14 | burnie
# Processing Record 33 of Set 14 | tucano
# Processing Record 34 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 35 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 14 | san carlos
# Processing Record 37 of Set 14 | juegang
# Processing Record 38 of Set 14 | whitehorse
# Processing Record 39 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 40 of Set 14 | hudson bay
# Processing Record 41 of Set 14 | cockburn town
# Processing Record 42 of Set 14 | svetlogorsk
# Processing Record 43 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 14 | havre-saint-pierre
# Processing Record 45 of Set 14 | benghazi
# Processing Record 46 of Set 14 | marang
# Processing Record 47 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 14 | batesville
# Processing Record 49 of Set 14 | kismayo
# Processing Record 50 of Set 14 | akhtanizovskaya
# Processing Record 1 of Set 15 | jian
# Processing Record 2 of Set 15 | hailey
# Processing Record 3 of Set 15 | tsentralnyy
# City not found. Skipping...
# Processing Record 4 of Set 15 | pacific grove
# Processing Record 5 of Set 15 | cabedelo
# Processing Record 6 of Set 15 | abu kamal
# Processing Record 7 of Set 15 | north myrtle beach
# Processing Record 8 of Set 15 | kovacica
# Processing Record 9 of Set 15 | imbituba
# Processing Record 10 of Set 15 | erenhot
# Processing Record 11 of Set 15 | mezen
# Processing Record 12 of Set 15 | karratha
# Processing Record 13 of Set 15 | sakaiminato
# Processing Record 14 of Set 15 | jardim
# Processing Record 15 of Set 15 | georgiyevskoye
# Processing Record 16 of Set 15 | ubatuba
# Processing Record 17 of Set 15 | bagdarin
# Processing Record 18 of Set 15 | saint anthony
# Processing Record 19 of Set 15 | wakkanai
# Processing Record 20 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 21 of Set 15 | koumra
# Processing Record 22 of Set 15 | batagay
# Processing Record 23 of Set 15 | lodja
# Processing Record 24 of Set 15 | darnetal
# Processing Record 25 of Set 15 | tahe
# Processing Record 26 of Set 15 | moerai
# Processing Record 27 of Set 15 | kawalu
# Processing Record 28 of Set 15 | kapoeta
# Processing Record 29 of Set 15 | luau
# Processing Record 30 of Set 15 | bourail
# Processing Record 31 of Set 15 | datong
# Processing Record 32 of Set 15 | denpasar
# Processing Record 33 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 15 | isabela
# Processing Record 35 of Set 15 | luwuk
# Processing Record 36 of Set 15 | ruidoso
# Processing Record 37 of Set 15 | chara
# Processing Record 38 of Set 15 | riberalta
# Processing Record 39 of Set 15 | marawi
# Processing Record 40 of Set 15 | berbera
# Processing Record 41 of Set 15 | tougan
# Processing Record 42 of Set 15 | ruhengeri
# Processing Record 43 of Set 15 | sabha
# Processing Record 44 of Set 15 | san diego de los banos
# Processing Record 45 of Set 15 | kabalo
# Processing Record 46 of Set 15 | gamboula
# Processing Record 47 of Set 15 | chirawa
# Processing Record 48 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 15 | wattegama
# Processing Record 50 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 16 | siderno
# Processing Record 2 of Set 16 | uznach
# Processing Record 3 of Set 16 | akyab
# Processing Record 4 of Set 16 | muhos
# Processing Record 5 of Set 16 | nalut
# Processing Record 6 of Set 16 | kitimat
# Processing Record 7 of Set 16 | yerbogachen
# Processing Record 8 of Set 16 | waipawa
# Processing Record 9 of Set 16 | atbasar
# Processing Record 10 of Set 16 | patos de minas
# Processing Record 11 of Set 16 | rock sound
# Processing Record 12 of Set 16 | pangnirtung
# Processing Record 13 of Set 16 | barra do garcas
# Processing Record 14 of Set 16 | angoche
# Processing Record 15 of Set 16 | seydisehir
# Processing Record 16 of Set 16 | uruguaiana
# Processing Record 17 of Set 16 | xichang
# Processing Record 18 of Set 16 | kirensk
# Processing Record 19 of Set 16 | adrar
# Processing Record 20 of Set 16 | tanete
# Processing Record 21 of Set 16 | sinnamary
# Processing Record 22 of Set 16 | tezu
# Processing Record 23 of Set 16 | conceicao do almeida
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
print(city_data_df.head(10))
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Cidreira -30.1811  -50.2056     66.29        88           8        9.86
# 1         Lebu -37.6167  -73.6500     52.00        92          17        8.86
# 2         Hilo  19.7297 -155.0900     72.63        91          40        6.91
# 3    Bathsheba  13.2167  -59.5167     81.21        83          75       25.32
# 4       Banjar  -8.1900  114.9675     76.91        89         100        2.73
# 5     Victoria  22.2855  114.1577     71.26        37          19        1.99
# 6   Georgetown   5.4112  100.3354     87.75        74          40        4.61
# 7  San Quintin  30.4833 -115.9500     60.75        72           0        2.84
# 8      Rikitea -23.1203 -134.9692     76.41        76           0       20.69
# 9   Borogontsy  62.6683  131.1683    -11.18        96         100        7.87
#
#   Country Current Description                 Date
# 0      BR           clear sky  2021-12-01 05:29:18
# 1      CL          few clouds  2021-12-01 05:28:01
# 2      US          light rain  2021-12-01 05:26:49
# 3      BB       broken clouds  2021-12-01 05:35:29
# 4      ID          light rain  2021-12-01 05:35:29
# 5      HK          few clouds  2021-12-01 05:27:44
# 6      MY    scattered clouds  2021-12-01 05:30:04
# 7      MX           clear sky  2021-12-01 05:35:30
# 8      PF           clear sky  2021-12-01 05:28:07
# 9      RU     overcast clouds  2021-12-01 05:35:30

# %%
new_column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Cidreira      BR -30.1811  -50.2056     66.29        88
# 1                    Lebu      CL -37.6167  -73.6500     52.00        92
# 2                    Hilo      US  19.7297 -155.0900     72.63        91
# 3               Bathsheba      BB  13.2167  -59.5167     81.21        83
# 4                  Banjar      ID  -8.1900  114.9675     76.91        89
# ..                    ...     ...      ...       ...       ...       ...
# 699                 Adrar      MR  20.5022  -10.0711     60.62        18
# 700                Tanete      ID  -3.9443  119.7848     79.77        86
# 701             Sinnamary      GF   5.3833  -52.9500     77.18        91
# 702                  Tezu      IN  27.9167   96.1667     81.14        26
# 703  Conceicao Do Almeida      BR -12.7794  -39.1700     72.91        89
#
#      Cloudiness  Wind Speed Current Description
# 0             8        9.86           clear sky
# 1            17        8.86          few clouds
# 2            40        6.91          light rain
# 3            75       25.32       broken clouds
# 4           100        2.73          light rain
# ..          ...         ...                 ...
# 699          95       10.02     overcast clouds
# 700         100        3.47     overcast clouds
# 701          97       10.09     overcast clouds
# 702           8        3.20           clear sky
# 703         100        2.46     overcast clouds
#
# [704 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
